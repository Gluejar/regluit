# %% [markdown]
# # Goals of this notebook
#
# * instantiate a new EC2 instance with which to build a new image
# * configure the instance -- what's involved?  Essentially turn https://github.com/Gluejar/regluit/blob/master/README.md into a fabric script
# * security group
# * database
# * database security group
# * IAM
# * elastic IP
#
#
# I'm starting to figure out the pieces using this IPython notebook, but ultimately what am I producing?  Something that Eric and Andromeda can run:
#
# * a set of fabric commands (https://github.com/Gluejar/regluit/blob/master/fabfile.py)?
# * some other form?

# %% [markdown]
# # Moving to ansible

# %%
from regluit.sysadmin import aws
reload(aws)
# Out:
# <module 'regluit.sysadmin.aws' from '/Users/raymondyee/C/src/Gluejar/regluit/sysadmin/aws.pyc'>

# %%
# look up Ubuntu EC2 image ids from alestic.com
# us-east-1 Ubuntu 12.04 LTS Precise
# EBS boot	ami-e7582d8e

#AMI_UBUNTU_12_04_ID = 'ami-79c0ae10' # older one
#AMI_UBUNTU_12_04_ID = 'ami-e7582d8e' # ubuntu-precise-12.04-amd64-server-20130603
AMI_UBUNTU_12_04_ID = 'ami-53b1ff3a' # ubuntu-precise-12.04-amd64-server-20130909
image = aws.ec2.get_all_images(image_ids=[AMI_UBUNTU_12_04_ID])[0]

# %%
# name of image follows Eric Hammond's convention of dating the images

image.id, image.name
# Out:
# (u'ami-53b1ff3a',
#  u'ubuntu/images/ebs/ubuntu-precise-12.04-amd64-server-20130909')

# %%
# sometimes we have an instance running or created already
# so we just need to get a reference to it (instead of creating a new one)

instance = aws.instance('please_unglue_it')
instance, instance.state
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e783b2284572> in <module>()
#       3
#       4 instance = aws.instance('please_unglue_it')
# ----> 5 instance, instance.state
#
# AttributeError: 'NoneType' object has no attribute 'state'

# %%
if instance.state == 'stopped':
    instance.start()

# %%
# launch a new instance
# use default security group for now -- probably want to make a new one

INSTANCE_NAME = 'please_unglue_it'
SECURITY_GROUP_NAME = 'please_unglue_it_sg1'

(instance, cmd) = aws.launch_instance(ami=AMI_UBUNTU_12_04_ID, 
                                      instance_type='t1.micro',
                                      key_name='rdhyee_public_key',
                                      group_name=SECURITY_GROUP_NAME,
                                      tag='new_instance',
                                      cmd_shell=False)

# add name

instance.add_tag('Name', INSTANCE_NAME)
# Out:
# Security Group: please_unglue_it_sg1 already authorized
# waiting for instance
# .
# .
# .
# .
# .
# done

# %%
instance.update()
# Out:
# u'running'

# %%
# configure security group testsg1

PORTS_TO_OPEN = [80, 443]

for port in PORTS_TO_OPEN:
    aws.ec2.authorize_security_group(group_name=SECURITY_GROUP_NAME, ip_protocol='tcp', from_port=port, to_port=port,
         cidr_ip='0.0.0.0/0')

# %%
console_output = instance.get_console_output()

# %%
# it takes time for the console output to show not be None -- I don't know exactly how long

print console_output.output

# %%
# http://ubuntu-smoser.blogspot.com/2010/07/verify-ssh-keys-on-ec2-instances.html

[line for line in console_output.output.split("\n") if line.startswith("ec2")]

# %%
instance_id = instance.id
instance_id

# %%
output = !source ~/gj_aws.sh; ec2-get-console-output $instance_id  | grep -i ec2

# %%
output

# %%
# copy a command to ssh into the instance

cmdstring = "ssh -oStrictHostKeyChecking=no ubuntu@{0}".format(instance.dns_name)
# works on a mac
! echo "$cmdstring" | pbcopy
cmdstring
# Out:
# 'ssh -oStrictHostKeyChecking=no ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com'

# %% [markdown]
# # dynamic execution of fabric tasks to setup the instance

# %%
# http://docs.fabfile.org/en/1.6/usage/execution.html#using-execute-with-dynamically-set-host-lists

import fabric
from fabric.api import run, local, env, cd, sudo, prefix, put
from fabric.operations import get
from contextlib import contextmanager as _contextmanager


from regluit.sysadmin import aws
from StringIO import StringIO

import github

# uncomment for debugging
# github.enable_console_debug_logging()

from github import Github

from django.conf import settings 

# allow us to use our ssh config files (e.g., ~/.ssh/config)
env.use_ssh_config = True

GITHUB_REPO_NAME = "Gluejar/regluit"
#GITHUB_REPO_NAME = "rdhyee/working-open-data"

# maybe generate some random pw -- not sure how important it is to generate some complicated PW if we configure 
# security groups properly
MYSQL_ROOT_PW = "unglueit_pw_123"


# http://stackoverflow.com/a/5359988/7782

env.directory = '/opt/regluit'
env.activate = 'source /opt/regluit/ENV/bin/activate'

@_contextmanager
def virtualenv():
    with cd(env.directory):
        with prefix(env.activate):
            yield



# can use 3 different types of authn: https://github.com/jacquev6/PyGithub/issues/15
# can be empty, username/pw, or personal API token (https://github.com/blog/1509-personal-api-tokens)
g = Github(settings.GITHUB_AUTH_TOKEN)

def host_type():
    run('uname -s')
    
def deploy():
    sudo("aptitude update")
    sudo("yes | aptitude upgrade")
    sudo("yes | aptitude install git-core apache libapache2-mod-wsgi mysql-client python-virtualenv python-mysqldb redis-server python-lxml")
    sudo("yes | aptitude install python-dev")
    sudo("yes | aptitude install libmysqlclient-dev")
    sudo("yes | apt-get update --fix-missing")
    sudo("yes | apt-get install libxml2-dev libxslt1-dev") 
    sudo("yes | apt-get install python-setuptools")
    sudo("yes | apt-get install python-dev")
 
    # http://www.whatastruggle.com/postfix-non-interactive-install
    sudo("DEBIAN_FRONTEND='noninteractive' apt-get install -y -q --force-yes postfix")

    sudo ("mkdir /opt/regluit")
    sudo ("chown ubuntu:ubuntu /opt/regluit")

    run('git config --global user.name "Raymond Yee"')
    run('git config --global user.email "rdhyee@gluejar.com"')

    run('ssh-keygen -b 2048 -t rsa -f /home/ubuntu/.ssh/id_rsa -P ""')

    # how to get the key and push it to github
    s = StringIO()
    get('/home/ubuntu/.ssh/id_rsa.pub', s)
    repo = g.get_repo(GITHUB_REPO_NAME)
    key = repo.create_key('please_unglue_it', s.getvalue())    
    
    # http://debuggable.com/posts/disable-strict-host-checking-for-git-clone:49896ff3-0ac0-4263-9703-1eae4834cda3
    run('echo -e "Host github.com\n\tStrictHostKeyChecking no\n" >> ~/.ssh/config')
    
    # clone the regluit git repo into /opt/regluit
    with cd("/opt"):
        run("yes | git clone git@github.com:Gluejar/regluit.git")
        
    #  for configuring local mysql server (5.5)
    #  http://stackoverflow.com/a/7740571/7782
    sudo("debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password password {0}'".format(MYSQL_ROOT_PW))
    sudo("debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password_again password {0}'".format(MYSQL_ROOT_PW))
    sudo("apt-get -y install mysql-server")
    
    # create regluit db an user
    
    command = """mysql -h 127.0.0.1 --user=root --password={0}   <<'EOF'

CREATE DATABASE regluit CHARACTER SET utf8 COLLATE utf8_bin;
CREATE USER 'regluit'@'localhost' IDENTIFIED BY 'regluit';

FLUSH PRIVILEGES;

GRANT ALL PRIVILEGES ON regluit.* TO 'regluit'@'localhost' WITH GRANT OPTION; 
EOF
""".format(MYSQL_ROOT_PW)
    run(command)       

    with cd("/opt/regluit"):
        run('virtualenv ENV')
    
    with virtualenv():
        # need to put back to master....
        run ("git checkout sysadmin")
        run ("git pull origin sysadmin")
        
        # hard coding of please
        sudo("ln -s /opt/regluit/deploy/please.conf /etc/apache2/sites-available/please")
        
        run('pip install -r requirements_versioned.pip')
        
        run('echo "/opt/regluit/" > ENV/lib/python2.7/site-packages/regluit.pth')
        run('echo "/opt/" > ENV/lib/python2.7/site-packages/opt.pth')
        
        run('django-admin.py syncdb --migrate --noinput --settings regluit.settings.please')
        
        sudo('mkdir /var/www/static')
        sudo('chown ubuntu:ubuntu /var/www/static')
        
        run('django-admin.py collectstatic  --noinput --settings regluit.settings.please')
        
        sudo('a2dissite 000-default')
        sudo('a2ensite please')
        sudo('a2enmod ssl rewrite')

    # SSL keys
    put("/Volumes/ryvault1/gluejar/other_keys/unglue_it/STAR_unglue_it.crt", 
            "/etc/ssl/certs/server.crt", use_sudo=True, mode=0664)
    put("/Volumes/ryvault1/gluejar/other_keys/unglue_it/server.key",
               "/etc/ssl/private/server.key", use_sudo=True, mode=0600)
    put("/Volumes/ryvault1/gluejar/other_keys/unglue_it/STAR_unglue_it.ca-bundle",
               "/etc/ssl/certs/STAR_unglue_it.ca-bundle", use_sudo=True, mode=0600)
    
    sudo ("/etc/init.d/apache2 restart")

   
    with cd("/opt/regluit"):

        sudo ("yes | adduser --no-create-home celery --disabled-password --disabled-login")
        sudo ("cp deploy/celeryd /etc/init.d/celeryd")
        sudo ("chmod 755 /etc/init.d/celeryd")
        sudo ("cp deploy/celeryd.conf /etc/default/celeryd")
        sudo ("mkdir /var/log/celery")
        sudo ("mkdir /var/run/celery")
        sudo ("chown celery:celery /var/log/celery /var/run/celery")
        sudo ("/etc/init.d/celeryd start")
        sudo ("cp deploy/celerybeat /etc/init.d/celerybeat")
        sudo ("chmod 755 /etc/init.d/celerybeat")
        sudo ("cp deploy/celerybeat.conf /etc/default/celerybeat")
        sudo ("mkdir /var/log/celerybeat")
        sudo ("chown celery:celery /var/log/celerybeat")
        sudo ("/etc/init.d/celerybeat start")    
    

 # TO DO write some code to use route53 to bind please.unglue.it to the ip address of the new instance
    
    (candidate_rrset, rrsets) = aws.route53_records('unglue.it', 'please', 'A')
    
    #http://hackinghabits.com/2011/08/20/boto-for-amazon-route53/
    # even for deletion, value and TTL have to match record to delete. 
    
    if len(candidate_rrset) == 1: # assuming we should 0 or 1
        r = candidate_rrset[0]
        r.resource_records[0], r.ttl, r.name, r.type
        change = rrsets.add_change("DELETE","please.unglue.it", r.type, ttl=r.ttl)
        change.add_value(r.resource_records[0])
        rrsets.commit()
    
        
    instance = aws.instance('please_unglue_it')
    
    change = rrsets.add_change("CREATE", 'please.unglue.it.', 'A', 60)
    change.add_value(instance.ip_address)
    rrsets.commit()

def test_mysql_connection():
    # test connectivity to mysql-server
    command = """mysql -h 127.0.0.1 --user=root --password={0}   <<'EOF'

SHOW VARIABLES;
EOF
""".format(MYSQL_ROOT_PW)
    run(command)   
    

def deploy_next():
    

    pass


        
    
#hosts = ['ubuntu@ec2-75-101-232-46.compute-1.amazonaws.com']
hosts = ["ubuntu@{0}".format(instance.dns_name)]

fabric.tasks.execute(deploy, hosts=hosts)
# Out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] Executing task 'deploy'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: aptitude update
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Writing extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Writing extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 0% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 1 http://us-east-1.ec2.archive.ubuntu.com precise Release.gpg [198 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 0% [1 Release.gpg 0 B/198 B 0%] [Connecting to security.ubuntu.com (91.189.91.15
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [Connecting to security.ubuntu.com (91.189.91.15)]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 2 http://us-east-1.ec2.archive.ubuntu.com precise-updates Release.gpg [198 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 50% [2 Release.gpg 0 B/198 B 0%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 3 http://us-east-1.ec2.archive.ubuntu.com precise Release [49.6 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 1% [3 Release 0 B/49.6 kB 0%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 4 http://security.ubuntu.com precise-security Release.gpg [198 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 1% [3 Release 0 B/49.6 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 5 http://security.ubuntu.com precise-security Release [49.6 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 86% [5 Release 35.8 kB/49.6 kB 72%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [3 Release gpgv 49.6 kB] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 6 http://us-east-1.ec2.archive.ubuntu.com precise-updates Release [49.6 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 70% [3 Release gpgv 49.6 kB] [6 Release 5,479 B/49.6 kB 11%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [3 Release gpgv 49.6 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 7 http://us-east-1.ec2.archive.ubuntu.com precise/main Sources [934 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [6 Release gpgv 49.6 kB] [7 Sources 6,943 B/934 kB 1%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 16% [7 Sources 26.2 kB/934 kB 3%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 8 http://security.ubuntu.com precise-security/main Sources [103 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 20% [7 Sources 80.2 kB/934 kB 9%] [8 Sources 6,839 B/103 kB 7%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [8 Sources 103 kB/103 kB 100%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 9 http://us-east-1.ec2.archive.ubuntu.com precise/universe Sources [5,019 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 19% [7 Sources bzip2] [9 Sources 4,022 B/5,019 kB 0%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 10 http://security.ubuntu.com precise-security/universe Sources [30.9 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 20% [7 Sources bzip2] [9 Sources 21.8 kB/5,019 kB 0%] [10 Sources 19.9 kB/30.9 k
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 20% [7 Sources bzip2] [9 Sources 30.5 kB/5,019 kB 1%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 11 http://security.ubuntu.com precise-security/main amd64 Packages [380 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 21% [7 Sources bzip2] [9 Sources 121 kB/5,019 kB 2%] [11 Packages 31.5 kB/380 kB
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 38% [7 Sources bzip2] [9 Sources 885 kB/5,019 kB 18%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 12 http://security.ubuntu.com precise-security/universe amd64 Packages [91.9 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 40% [7 Sources bzip2] [9 Sources 1,042 kB/5,019 kB 21%] [12 Packages 61.9 kB/91.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 41% [7 Sources bzip2] [9 Sources 1,042 kB/5,019 kB 21%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 13 http://security.ubuntu.com precise-security/main i386 Packages [407 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 42% [7 Sources bzip2] [9 Sources 1,298 kB/5,019 kB 26%] [13 Packages 2,495 B/407
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 53% [7 Sources bzip2] [9 Sources 1,652 kB/5,019 kB 33%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 14 http://security.ubuntu.com precise-security/universe i386 Packages [96.5 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 55% [7 Sources bzip2] [9 Sources 1,863 kB/5,019 kB 37%] [14 Packages 35.8 kB/96.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 56% [7 Sources bzip2] [9 Sources 1,863 kB/5,019 kB 37%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 15 http://security.ubuntu.com precise-security/main TranslationIndex [74 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 60% [7 Sources bzip2] [9 Sources 2,110 kB/5,019 kB 42%] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 16 http://security.ubuntu.com precise-security/universe TranslationIndex [73 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 61% [7 Sources bzip2] [9 Sources 2,241 kB/5,019 kB 45%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 17 http://security.ubuntu.com precise-security/main Translation-en [178 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 62% [7 Sources bzip2] [9 Sources 2,371 kB/5,019 kB 47%] [17 Translation-en 11.3
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 66% [7 Sources bzip2] [9 Sources 2,520 kB/5,019 kB 50%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 18 http://security.ubuntu.com precise-security/universe Translation-en [56.7 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 67% [7 Sources bzip2] [9 Sources 2,596 kB/5,019 kB 52%] [18 Translation-en 2,599
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 80% [7 Sources bzip2] [9 Sources 3,514 kB/5,019 kB 70%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [7 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 19 http://us-east-1.ec2.archive.ubuntu.com precise/main amd64 Packages [1,273 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 85% [7 Sources bzip2] [19 Packages 1,102 B/1,273 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 91% [19 Packages 467 kB/1,273 kB 37%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [8 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 20 http://us-east-1.ec2.archive.ubuntu.com precise/universe amd64 Packages [4,786 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 65% [8 Sources bzip2] [20 Packages 1,102 B/4,786 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 67% [20 Packages 301 kB/4,786 kB 6%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 70% [20 Packages 667 kB/4,786 kB 14%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [11 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 21 http://us-east-1.ec2.archive.ubuntu.com precise/main i386 Packages [1,274 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 91% [11 Packages bzip2] [21 Packages 11.6 kB/1,274 kB 1%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 92% [21 Packages 132 kB/1,274 kB 10%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [21 Packages 1,195 kB/1,274 kB 94%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [13 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 22 http://us-east-1.ec2.archive.ubuntu.com precise/universe i386 Packages [4,796 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 76% [13 Packages bzip2] [22 Packages 14.5 kB/4,796 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [22 Packages 4,796 kB/4,796 kB 100%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 23 http://us-east-1.ec2.archive.ubuntu.com precise/main TranslationIndex [3,706 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [14 Packages bzip2] [23 TranslationIndex 1,100 B/3,706 B 30%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [14 Packages bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 24 http://us-east-1.ec2.archive.ubuntu.com precise/universe TranslationIndex [2,922 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [14 Packages bzip2] [24 TranslationIndex 2,922 B/2,922 B 100%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [14 Packages bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 25 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main Sources [456 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 98% [14 Packages bzip2] [25 Sources 15.9 kB/456 kB 3%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [14 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 26 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe Sources [107 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [17 Translation-en bzip2] [26 Sources 4,023 B/107 kB 4%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [17 Translation-en bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 27 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main amd64 Packages [772 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 96% [17 Translation-en bzip2] [27 Packages 17.4 kB/772 kB 2%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [17 Translation-en bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 28 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe amd64 Packages [240 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [17 Translation-en bzip2] [28 Packages 5,483 B/240 kB 2%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [17 Translation-en bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 29 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main i386 Packages [801 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 96% [17 Translation-en bzip2] [29 Packages 6,943 B/801 kB 1%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [29 Packages 738 kB/801 kB 92%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [18 Translation-en bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 30 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe i386 Packages [246 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 99% [18 Translation-en bzip2] [30 Packages 6,943 B/246 kB 3%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [30 Packages 212 kB/246 kB 86%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 31 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main TranslationIndex [3,564 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2] [31 TranslationIndex 1,100 B/3,564 B 31%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 32 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe TranslationIndex [2,850 B]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2] [32 TranslationIndex 1,100 B/2,850 B 39%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 33 http://us-east-1.ec2.archive.ubuntu.com precise/main Translation-en [726 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 97% [9 Sources bzip2] [33 Translation-en 5,483 B/726 kB 1%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 34 http://us-east-1.ec2.archive.ubuntu.com precise/universe Translation-en [3,341 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 87% [9 Sources bzip2] [34 Translation-en 17.4 kB/3,341 kB 1%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Hit http://us-east-1.ec2.archive.ubuntu.com precise-updates/main Translation-en
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Hit http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe Translation-en
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [9 Sources bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [19 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [20 Packages bzip2]                                           4,265 kB/s 0s
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]                                                     4,265 kB/s 0s
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [21 Packages bzip2]                                           4,265 kB/s 0s
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]                                                     4,265 kB/s 0s
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [22 Packages bzip2]                                           4,265 kB/s 0s
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [22 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [27 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [29 Packages bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [34 Translation-en bzip2]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Fetched 26.3 MB in 19s (1,367 kB/s)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Reading package lists
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Reading package lists
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Current status: 98 updates [+98], 1122 new [+1122].
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: yes | aptitude upgrade
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Reading package lists
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Reading package lists
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Building dependency tree
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Building dependency tree
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Reading state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Reading state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Reading extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Reading extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Initializing package states
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Resolving dependencies...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: The following NEW packages will be installed:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   linux-headers-3.2.0-61{a} linux-headers-3.2.0-61-virtual{a}
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   linux-image-3.2.0-61-virtual{a}
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: The following packages will be REMOVED:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   gir1.2-gudev-1.0{u} libgudev-1.0-0{u}
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: The following packages will be upgraded:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   accountsservice apport apt apt-transport-https apt-utils apt-xapian-index
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   base-files bc bind9-host ca-certificates cloud-init cloud-utils curl
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   dmsetup dnsutils dpkg file gnupg gpgv grub-common grub-legacy-ec2 grub-pc
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   grub-pc-bin grub2-common ifupdown initramfs-tools initramfs-tools-bin
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   iproute isc-dhcp-client isc-dhcp-common landscape-client landscape-common
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   language-selector-common libaccountsservice0 libapt-inst1.4
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libapt-pkg4.12 libbind9-80 libc-bin libc6 libcurl3 libcurl3-gnutls
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libdevmapper1.02.1 libdns81 libdrm-intel1 libdrm-nouveau1a libdrm-radeon1
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libdrm2 libglib2.0-0 libgnutls26 libisc83 libisccc80 libisccfg82
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libldap-2.4-2 liblockfile-bin liblockfile1 liblwres80 libmagic1
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libpolkit-gobject-1-0 libpython2.7 libssl1.0.0 libudev0 libx11-6
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libx11-data libyaml-0-2 linux-firmware linux-headers-virtual
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   linux-image-virtual linux-virtual multiarch-support openssh-client
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   openssh-server openssl perl perl-base perl-modules procps python-apport
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   python-apt python-apt-common python-boto python-httplib2
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   python-lazr.restfulclient python-openssl python-problem-report
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   python-software-properties python2.7 python2.7-minimal rsyslog sudo
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   tzdata udev update-manager-core w3m whoopsie wpasupplicant xkb-data
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: The following packages are RECOMMENDED but will NOT be installed:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   libatm1 libglib2.0-data shared-mime-info shared-mime-info:i386
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 96 packages upgraded, 3 newly installed, 2 to remove and 0 not upgraded.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Need to get 98.0 MB of archives. After unpacking 112 MB will be used.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Do you want to continue? [Y/n/?]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [  0%] Writing extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: [100%] Writing extended state information
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 0% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 1 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libc-bin amd64 2.15-0ubuntu10.5 [1,182 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 0% [1 libc-bin 0 B/1,182 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 1% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 2 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libc6 amd64 2.15-0ubuntu10.5 [4,654 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 1% [2 libc6 0 B/4,654 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 6% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 3 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main tzdata all 2014a-0ubuntu0.12.04 [448 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 6% [3 tzdata 0 B/448 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 6% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 4 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libssl1.0.0 amd64 1.0.1-4ubuntu5.12 [1,048 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 6% [4 libssl1.0.0 0 B/1,048 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 7% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 5 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libpython2.7 amd64 2.7.3-0ubuntu3.5 [1,188 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 7% [5 libpython2.7 0 B/1,188 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 9% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 6 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python2.7 amd64 2.7.3-0ubuntu3.5 [2,675 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 9% [6 python2.7 0 B/2,675 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 11% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 7 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python2.7-minimal amd64 2.7.3-0ubuntu3.5 [1,743 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 11% [7 python2.7-minimal 0 B/1,743 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 13% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 8 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python-apt-common all 0.8.3ubuntu7.2 [22.2 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 13% [8 python-apt-common 0 B/22.2 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 13% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 9 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libapt-pkg4.12 amd64 0.8.16~exp12ubuntu10.16 [936 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 13% [9 libapt-pkg4.12 0 B/936 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 10 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libapt-inst1.4 amd64 0.8.16~exp12ubuntu10.16 [102 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [10 libapt-inst1.4 0 B/102 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 11 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python-apt amd64 0.8.3ubuntu7.2 [187 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [11 python-apt 0 B/187 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 12 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main openssl amd64 1.0.1-4ubuntu5.12 [523 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 14% [12 openssl 0 B/523 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 15% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 13 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main ca-certificates all 20130906ubuntu0.12.04.1 [192 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 15% [13 ca-certificates 0 B/192 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 15% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 14 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main dpkg amd64 1.16.1.2ubuntu7.3 [1,829 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 15% [14 dpkg 0 B/1,829 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 15 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main bc amd64 1.06.95-2ubuntu1 [91.1 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [15 bc 0 B/91.1 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 16 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main landscape-client amd64 13.07.3-0ubuntu0.12.04 [20.3 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [16 landscape-client 0 B/20.3 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 17 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main landscape-common amd64 13.07.3-0ubuntu0.12.04 [206 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [17 landscape-common 0 B/206 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 18 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main base-files amd64 6.5ubuntu6.7 [61.0 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [18 base-files 0 B/61.0 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Get: 19 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main perl amd64 5.14.2-6ubuntu2.4 [4,411 kB]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 17% [19 perl 0 B/4,411 kB 0%]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# ...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/deleted-overlay.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-restore-8bit.png'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_searchbox.png'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/changelist-bg.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/chooser-bg.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_addlink.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_deletelink.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_alert.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tool-left.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon-no.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tooltag-add_over.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg-reverse.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg-grabber.gif'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/gis/move_vertex_on.png'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/gis/move_vertex_off.png'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/ie.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/dashboard.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/base.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/changelists.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/login.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/widgets.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/forms.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Copying '/opt/regluit/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/rtl.css'
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 662 static files copied.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: a2dissite 000-default
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Site default disabled.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: To activate the new configuration, you need to run:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   service apache2 reload
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: a2ensite please
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Enabling site please.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: To activate the new configuration, you need to run:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   service apache2 reload
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: a2enmod ssl rewrite
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Enabling module ssl.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: See /usr/share/doc/apache2.2-common/README.Debian.gz on how to configure SSL and create self-signed certificates.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Enabling module rewrite.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: To activate the new configuration, you need to run:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   service apache2 restart
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] put: /Volumes/ryvault1/gluejar/other_keys/unglue_it/STAR_unglue_it.crt -> /etc/ssl/certs/server.crt
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] put: /Volumes/ryvault1/gluejar/other_keys/unglue_it/server.key -> /etc/ssl/private/server.key
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] put: /Volumes/ryvault1/gluejar/other_keys/unglue_it/STAR_unglue_it.ca-bundle -> /etc/ssl/certs/STAR_unglue_it.ca-bundle
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: /etc/init.d/apache2 restart
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:  * Restarting web server apache2
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:  ... waiting    ...done.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: yes | adduser --no-create-home celery --disabled-password --disabled-login
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Adding user `celery' ...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Adding new group `celery' (1001) ...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Adding new user `celery' (1001) with group `celery' ...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Not creating home directory `/home/celery'.
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Changing the user information for celery
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Enter the new value, or press ENTER for the default
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 	Full Name []: 	Room Number []: 	Work Phone []: 	Home Phone []: 	Other []: Is the information correct? [Y/n]
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: cp deploy/celeryd /etc/init.d/celeryd
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: chmod 755 /etc/init.d/celeryd
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: cp deploy/celeryd.conf /etc/default/celeryd
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: mkdir /var/log/celery
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: mkdir /var/run/celery
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: chown celery:celery /var/log/celery /var/run/celery
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: /etc/init.d/celeryd start
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: activating virtualenv /opt/regluit/ENV/bin/activate
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: celeryd-multi v3.0.9 (Chiastic Slide)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: > Starting nodes...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: 	> w1.ip-10-167-1-34: OK
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: cp deploy/celerybeat /etc/init.d/celerybeat
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: chmod 755 /etc/init.d/celerybeat
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: cp deploy/celerybeat.conf /etc/default/celerybeat
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: mkdir /var/log/celerybeat
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: chown celery:celery /var/log/celerybeat
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] sudo: /etc/init.d/celerybeat start
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Starting celerybeat...
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: Traceback (most recent call last):
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/bin/django-admin.py", line 5, in <module>
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     management.execute_from_command_line()
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/__init__.py", line 443, in execute_from_command_line
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     utility.execute()
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/__init__.py", line 382, in execute
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     self.fetch_command(subcommand).run_from_argv(self.argv)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/djcelery/management/base.py", line 74, in run_from_argv
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     return super(CeleryCommand, self).run_from_argv(argv)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/base.py", line 196, in run_from_argv
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     self.execute(*args, **options.__dict__)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/djcelery/management/base.py", line 67, in execute
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     super(CeleryCommand, self).execute(*args, **options)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/base.py", line 231, in execute
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     self.validate()
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/base.py", line 266, in validate
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     num_errors = get_validation_errors(s, app)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/core/management/validation.py", line 103, in get_validation_errors
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     connection.validation.validate_field(e, opts, f)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/db/backends/mysql/validation.py", line 14, in validate_field
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     db_version = self.connection.get_server_version()
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/db/backends/mysql/base.py", line 415, in get_server_version
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     self.cursor().close()
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/db/backends/__init__.py", line 319, in cursor
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     cursor = util.CursorWrapper(self._cursor(), self)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/django/db/backends/mysql/base.py", line 387, in _cursor
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     self.connection = Database.connect(**kwargs)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/MySQLdb/__init__.py", line 81, in Connect
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     return Connection(*args, **kwargs)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:   File "/opt/regluit/ENV/local/lib/python2.7/site-packages/MySQLdb/connections.py", line 187, in __init__
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:     super(Connection, self).__init__(*args, **kwargs2)
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out: _mysql_exceptions.OperationalError: (2003, "Can't connect to MySQL server on 'production.cboagmr25pjs.us-east-1.rds.amazonaws.com' (110)")
# [ubuntu@ec2-54-234-182-8.compute-1.amazonaws.com] out:
# ---------------------------------------------------------------------------
# DNSServerError                            Traceback (most recent call last)
# <ipython-input-8-140993c484b6> in <module>()
#     203 hosts = ["ubuntu@{0}".format(instance.dns_name)]
#     204
# --> 205 fabric.tasks.execute(deploy, hosts=hosts)
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/fabric/tasks.pyc in execute(task, *args, **kwargs)
#     314                 results[host] = _execute(
#     315                     task, host, my_env, args, new_kwargs, jobs, queue,
# --> 316                     multiprocessing
#     317                 )
#     318             except NetworkError, e:
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/fabric/tasks.pyc in _execute(task, host, my_env, args, kwargs, jobs, queue, multiprocessing)
#     211     else:
#     212         with settings(**local_env):
# --> 213             return task.run(*args, **kwargs)
#     214
#     215 def _is_task(task):
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/fabric/tasks.pyc in run(self, *args, **kwargs)
#     121
#     122     def run(self, *args, **kwargs):
# --> 123         return self.wrapped(*args, **kwargs)
#     124
#     125     def __getattr__(self, k):
#
# <ipython-input-8-140993c484b6> in deploy()
#     180     change = rrsets.add_change("CREATE", 'please.unglue.it.', 'A', 60)
#     181     change.add_value(instance.ip_address)
# --> 182     rrsets.commit()
#     183
#     184 def test_mysql_connection():
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/boto/route53/record.pyc in commit(self)
#     147             import boto
#     148             self.connection = boto.connect_route53()
# --> 149         return self.connection.change_rrsets(self.hosted_zone_id, self.to_xml())
#     150
#     151     def endElement(self, name, value, connection):
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/boto/route53/connection.pyc in change_rrsets(self, hosted_zone_id, xml_body)
#     313             raise exception.DNSServerError(response.status,
#     314                                            response.reason,
# --> 315                                            body)
#     316         e = boto.jsonresponse.Element()
#     317         h = boto.jsonresponse.XmlHandler(e, None)
#
# DNSServerError: DNSServerError: 400 Bad Request
# <?xml version="1.0"?>
# <ErrorResponse xmlns="https://route53.amazonaws.com/doc/2012-02-29/"><Error><Type>Sender</Type><Code>InvalidChangeBatch</Code><Message>Tried to delete resource record set [name='please.unglue.it.', type='A'] but it was not found</Message></Error><RequestId>9b560376-cefd-11e3-ad13-4750056f7ce5</RequestId></ErrorResponse>

# %%
# the following code is prone to fail 

(candidate_rrset, rrsets) = aws.route53_records('unglue.it', 'please', 'A')


if len(candidate_rrset) == 1: # assuming we should 0 or 1
    r = candidate_rrset[0]
    r.resource_records[0], r.ttl, r.name, r.type
    change = rrsets.add_change("DELETE","please.unglue.it", r.type, ttl=r.ttl)
    change.add_value(r.resource_records[0])
    rrsets.commit()


instance = aws.instance('please_unglue_it')

change = rrsets.add_change("CREATE", 'please.unglue.it.', 'A', 60)
change.add_value(instance.ip_address)
rrsets.commit()
# Out:
# {u'ChangeResourceRecordSetsResponse': {u'ChangeInfo': {u'Comment': u'None',
#    u'Id': u'/change/CX7VP0CC7ZE3Q',
#    u'Status': u'PENDING',
#    u'SubmittedAt': u'2014-04-28T17:59:57.881Z'}}}

# %% [markdown]
# # Debugging route53

# %%
(candidate_rrset, rrsets) = aws.route53_records('unglue.it', 'please', 'A')
(candidate_rrset, rrsets)

# %%
len(candidate_rrset)

# %%
instance.ip_address

# %%
(candidate_rrset, rrsets) = aws.route53_records('unglue.it', 'please', 'A')

#http://hackinghabits.com/2011/08/20/boto-for-amazon-route53/
# even for deletion, value and TTL have to match record to delete. 

if len(candidate_rrset) == 1: # assuming we should 0 or 1
    r = candidate_rrset[0]
    r.resource_records[0], r.ttl, r.name, r.type
    change = rrsets.add_change("DELETE","please.unglue.it", r.type, ttl=r.ttl)
    change.add_value(r.resource_records[0])
    rrsets.commit()

    
instance = aws.instance('please_unglue_it')

change = rrsets.add_change("CREATE", 'please.unglue.it.', 'A', 60)
change.add_value(instance.ip_address)
rrsets.commit()

# %% [markdown]
# ## Commands to add?
#
# By the time we run through a lot of the fabric script, a reboot of the system is required.  After installing mysql locally, it seems that the instance needs to be rebooted.  Here's some code to do so.  Problem remaining is how to reboot, wait for reboot to be completed, and then pick up the next steps.
#
# I could issue a fabric command to apply security upgrade: `sudo unattended-upgrade`
#
# or
#
# I think there is a boto command to restart instance
#
#     *  `sudo unattended-upgrade`

# %%
rebooted_instance = instance.reboot()
rebooted_instance

# %%
# looks like reboot works, but that the instance status remains running throughout time reboot happens...
# maybe we wait a specific amount of time and the try to connect

# %% [markdown]
# # hand-installing things for expedient job on gluejar.com

# %% [markdown]
# * git repo

# %% [markdown]
# # EC2 security groups

# %% [markdown]
# * listing key existing security groups
# * how to copy parameters

# %%
# security groups


security_groups = aws.ec2.get_all_security_groups()
security_groups

# %%
# pull out the security group used for unglue.it

web_prod_sgroup = [(group.id, group.name, group.description, group.rules) for group in security_groups if group.name=='web-production'][0]

# %%
web_prod_sgroup

# %%
# http://boto.readthedocs.org/en/latest/security_groups.html
rules = web_prod_sgroup[3]
[(rule.ip_protocol, rule.from_port, rule.to_port, rule.grants, rule.groups) for rule in rules]

# %%
[(grant.cidr_ip) for grant in rule.grants]

# %%
[(grant.owner_id, grant.group_id, grant.name, grant.cidr_ip) for grant in rule.grants]

# %%
# let's make a new security group to replicate the web-production sg

test8_sg = aws.ec2.create_security_group('test8', 'test8 sg')

# %%
# You need to pass in either src_group_name OR ip_protocol, from_port, to_port, and cidr_ip.

test8_sg.authorize('tcp', 80, 80, '0.0.0.0/0')
test8_sg.authorize('tcp', 22, 22, '0.0.0.0/0')
test8_sg.authorize('tcp', 443, 443, '0.0.0.0/0')

# %%
test9_sg = aws.ec2.create_security_group('test9', 'test9 sg')

# %%
test9_sg.authorize(src_group=test8_sg)

# %%
test8_sg.rules

# %%
rules = test9_sg.rules
rule = rules[0]
grant = rule.grants[0]

# %%
(rule.ip_protocol, rule.from_port, rule.to_port, rule.grants)

# %%
grant.owner_id, grant.group_id, grant.name, grant.cidr_ip

# %%
test9_sg = [(group.id, group.name, group.description, group.rules) for group in security_groups if group.name=='test9'][0]

# %%
rules = test9_sg[3]
[(rule.ip_protocol, rule.from_port, rule.to_port, [(grant.owner_id, grant.group_id, grant.name, grant.cidr_ip) for grant in rule.grants], rule.groups) for rule in rules]

# %%
aws.ec2.authorize_security_group(group_name='test8', ip_protocol='tcp', from_port=80, to_port=80, cidr_ip='0.0.0.0/0')

# %%
# let's compute the instances that are tied to the various security groups
# http://boto.readthedocs.org/en/latest/ref/ec2.html#module-boto.ec2.securitygroup
# This calculation is useful for reconstructing the relationships among instances and security groups


from boto.ec2 import securitygroup

for security_group in aws.ec2.get_all_security_groups():
    sg = securitygroup.SecurityGroup(name=security_group.name, connection=aws.ec2)
    print security_group, [inst.id for inst in sg.instances()]

# %%
# with the exception of frontend-lb, let's delete the security groups that have no attached instances 

for sg in [sg for sg in aws.ec2.get_all_security_groups() if len(sg.instances()) == 0 and sg.name != 'frontend-lb']:
    print sg.name, sg.id, aws.ec2.delete_security_group(group_id=sg.id)

# %% [markdown]
# # Setting up MySQL

# %% [markdown]
# * plain old mysql on the server ( https://help.ubuntu.com/12.04/serverguide/mysql.html )
# * RDS parameters to figure out
#
# to run mysql on server -- if you didn't have to worry about interactivity:
#
# > `sudo apt-get install mysql-server`

# %%
"ubuntu@{0}".format(inst.dns_name)

# %%
# once mysql installed, how to test the basic connectivity?

# %% [markdown]
# <pre>
# sudo debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password password unglueit_pw_123'
# sudo debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password_again password unglueit_pw_123'
# sudo apt-get -y install mysql-server
# </pre>
#
# <pre>
# mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123
# </pre>

# %% [markdown]
#     mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123   <<'EOF'
#
#     SHOW DATABASES;
#     EOF

# %% [markdown]
# # Creating an Image out of Instance

# %%
instance.id

# %%
new_image = aws.ec2.create_image(instance.id, "script_built_after_local_mysql_2013-05-24", 
     description="next step figure out RDS")

# %%
# sometimes it really does take a surprisingly long time to make an image out of an instance

# new_image = aws.ec2.get_image(image_id=u'ami-853a51ec')
new_image

# %%
new_image = aws.ec2.get_image(new_image)

# %%
new_image.state

# %% [markdown]
# Fire up an instance

# %%
(instance, cmd) = aws.launch_instance(ami=u'ami-853a51ec', 
                                      instance_type='t1.micro',
                                      key_name='rdhyee_public_key',
                                      group_name=SECURITY_GROUP_NAME,
                                      tag='new_instance',
                                      cmd_shell=False)

# %% [markdown]
# # Route53

# %%
from regluit.sysadmin import aws
reload(aws)

(candidate_rrset, rrsets) = aws.route53_records('unglue.it', 'please', 'A')

#http://hackinghabits.com/2011/08/20/boto-for-amazon-route53/
# even for deletion, value and TTL have to match record to delete. 

if len(candidate_rrset) == 1: # assuming we should 0 or 1
    r = candidate_rrset[0]
    r.resource_records[0], r.ttl, r.name, r.type
    change = rrsets.add_change("DELETE","please.unglue.it", r.type, ttl=r.ttl)
    change.add_value(r.resource_records[0])
    rrsets.commit()

    
instance = aws.instance('please_unglue_it')

change = rrsets.add_change("CREATE", 'please.unglue.it.', 'A', 60)
change.add_value(instance.ip_address)
rrsets.commit()

# %% [markdown]
# # RDS

# %% [markdown]
# http://calculator.s3.amazonaws.com/calc5.html can be used to estimate costs
#
# A barebones micro rds costs about $20/month
#
# References:
#
# * [boto rds intro](http://boto.readthedocs.org/en/latest/rds_tut.html)
# * [boto rds api ref](http://boto.readthedocs.org/en/latest/ref/rds.html)

# %%
dbs = aws.all_rds()
dbs

# %%
db = dbs[1]
(db.id, db.allocated_storage, db.instance_class, db.engine, db.master_username, 
 db.parameter_group, db.security_group, db.availability_zone, db.multi_az)

# %%
# I forgot I already have a working rds db info displayer
aws.db_info(db)

# %%
# parameter group
# http://boto.readthedocs.org/en/latest/ref/rds.html#module-boto.rds.parametergroup

# I think functionality is more primitive

# %%
pg = aws.rds.get_all_dbparameters('production1')

# %%
rds = aws.rds

def parameter_group_iteritems(group_name):

    first_page = True
    get_next_page = True
    
    while get_next_page:
        if first_page:
            pg = rds.get_all_dbparameters(group_name)
            first_page = False
        else:
            pg = rds.get_all_dbparameters(group_name, marker = pg.Marker)
            
        for key in pg.keys():
            yield (key, pg[key])
    
        get_next_page = hasattr(pg, 'Marker')

# %%
# try to turn parameter group into a dict to enable reproducibiity of group

pg_dict = {}
for (key, param) in parameter_group_iteritems('production1'):
    try:
        key, {'name':param.name, 'type':param.type, 'description':param.description, 'value':param.value}
        pg_dict[key] = {'name':param.name, 'type':param.type, 'description':param.description, 'value':param.value}
    except Exception as e:
        print key, e

# %%
sorted(pg_dict.keys())

# %%
# https://github.com/boto/boto/blob/2.8.0/boto/rds/parametergroup.py#L71

param = pg_dict.get('character_set_database')
{'name':param["name"], 'type':param["type"], 'description':param["description"], 'value':param["value"]}

# %%
# security group

# %%
# how to create RDS
# db = conn.create_dbinstance("db-master-1", 10, 'db.m1.small', 'root', 'hunter2')

# %% [markdown]
# # IAM

# %% [markdown]
# good to get an automated handle of the IAM groups and users.  To use boto to manage IAM, you will need to have AWS keys with sufficient permissions.

# %%
from regluit.sysadmin import aws
iam = aws.boto.connect_iam()


IAM_POWER_USER_PERMISSION = """{
  "Version": "2012-10-17",
  "Statement": [
    {
      "Effect": "Allow",
      "NotAction": "iam:*",
      "Resource": "*"
    }
  ]
}"""


# get group names

def all_iam_group_names():
    return [g.group_name for g in iam.get_all_groups()['list_groups_response']['list_groups_result']['groups']]

# get user names

def all_iam_user_names():
    return [u.user_name for u in iam.get_all_users()[u'list_users_response'][u'list_users_result']['users']]

# mapping between groups and users
# list users and their corresponding groups.

def iam_group_names_for_user(user_name):
    return [g.group_name for g in iam.get_groups_for_user(user_name)['list_groups_for_user_response'][u'list_groups_for_user_result']['groups']]

# for given groups, list corresponding users

def iam_user_names_for_group(group_name):
    return [u.user_name for u in iam.get_group(group_name=group_name)[u'get_group_response'][u'get_group_result']['users']]

# find keys associated with user

def access_keys_for_user_name(user_name):
    keys = iam.get_all_access_keys(user_name=user_name)['list_access_keys_response'][u'list_access_keys_result']['access_key_metadata']
    return keys

# can we use IAM to create new IAM user and get the key / secret?

def create_iam_user(user_name, generate_key=True):
    iam_user = iam.create_user(user_name=user_name)
    if generate_key:
        key_output = iam.create_access_key(user_name=user_name)
        access_key = key_output['create_access_key_response']['create_access_key_result']['access_key']
        (key, secret) = (access_key['access_key_id'], access_key['secret_access_key'])
        return (iam_user, key, secret)
    else:
        return (iam_user, key, None, None)

def delete_iam_user(user_name):
    
    # check to see whether there is such a user_name.
    try:
        iam.get_user(user_name)
    except boto.exception.BotoServerError as e:
        return None

    # delete associated keys
    
    keys = access_keys_for_user_name(user_name)
    
    for key in keys:
        # print key.access_key_id, key.status
        iam.delete_access_key(access_key_id=key.access_key_id, user_name=user_name)
        #result = iam.update_access_key(access_key_id=key.access_key_id, user_name=user_name, status='Inactive')
        
    # also need to delete associated policies
    
    policy_names = iam_policy_names_for_user(user_name)
    
    for policy_name in policy_names:
        iam.delete_user_policy(user_name=user_name,policy_name=policy_name)
        
    # once the keys associated with the user are deleted, then proceed to delete the user

    result = iam.delete_user(user_name)
    return result
    
# policies

def iam_policy_names_for_group(group_name):
    return iam.get_all_group_policies(group_name=group_name)['list_group_policies_response'][u'list_group_policies_result']['policy_names']

def iam_policy_names_for_user(user_name):
    return iam.get_all_user_policies(user_name=user_name)['list_user_policies_response'][u'list_user_policies_result']['policy_names']

def policy_document(policy_name, user_name=None, group_name=None):
    if group_name is not None:
        document = iam.get_group_policy(group_name=group_name, policy_name=policy_name)[u'get_group_policy_response'][u'get_group_policy_result'][u'policy_document']
        return urlparse.parse_qs("policy={0}".format(document))['policy'][0]
    if user_name is not None:
        document = iam.get_user_policy(user_name=user_name, policy_name=policy_name)[u'get_user_policy_response'][u'get_user_policy_result'][u'policy_document']
        return urlparse.parse_qs("policy={0}".format(document))['policy'][0]
    
# get general IAM stats

(iam.get_account_summary(), all_iam_group_names(), all_iam_user_names(),
 iam_group_names_for_user('eric'), iam_user_names_for_group('gluejar'),
 access_keys_for_user_name('ry-dev')
 )

# %%
# test -> grab all groups and list of corresponding users

for g in all_iam_group_names():
    print g, iam_user_names_for_group(g)

# %%
# list all keys by looping through users

for u in all_iam_user_names():
    print u, [(k.access_key_id, k.status) for k in access_keys_for_user_name(u)]

# %%
# look at permission structures of groups and users

from urllib import urlencode
import urlparse

policy_names = iam_policy_names_for_group('gluejar')

for p in policy_names:
    print policy_document(group_name='gluejar', policy_name=p)

# %%
iam_user, key, secret = create_iam_user('ry-dev-3', True)
iam.put_user_policy( user_name='ry-dev-3', policy_name='power_user_2013-06-12', policy_json=IAM_POWER_USER_PERMISSION)

# %%
# write out a shell script for configuring the environment with the keys for AWS

print """#!/bin/bash


export AWS_ACCESS_KEY_ID={AWS_ACCESS_KEY_ID}
export AWS_SECRET_ACCESS_KEY={AWS_SECRET_ACCESS_KEY}

# EC2 API tools
export EC2_ACCESS_KEY=$AWS_ACCESS_KEY_ID
export EC2_SECRET_KEY=$AWS_SECRET_ACCESS_KEY""".format(**{'AWS_SECRET_ACCESS_KEY':secret, 'AWS_ACCESS_KEY_ID':key})

# %%
[policy_document(p, user_name='ry-dev-3') for p in iam_policy_names_for_user('ry-dev-3')]

# %%
delete_iam_user(user_name='ry-dev-3')

# %% [markdown]
# # Different ways to pass in AWS keys to boto
#
# http://boto.readthedocs.org/en/latest/boto_config_tut.html
#
# * Credentials passed into Connection class constructor.
# * Credentials specified by environment variables
# * Credentials specified as options in the config file.

# %% [markdown]
# <pre>
#
# #!/bin/bash
#
# export AWS_ACCESS_KEY={AWS_ACCESS_KEY}
# export AWS_SECRET_KEY={AWS_SECRET_KEY}
#
# # EC2 API tools
# export EC2_ACCESS_KEY=$AWS_ACCESS_KEY
# export EC2_SECRET_KEY=$AWS_SECRET_KEY
#
# </pre>

# %%
# %%bash
# # something to convert this notebook to Python source
# cd /Users/raymondyee/D/Document/Gluejar/Gluejar.github/regluit; python ~/C/src/nbconvert/nbconvert.py python build_ec2_instances_for_django.ipynb

# %%
import fabric
from fabric.api import run, local, env, cd, sudo
from fabric.operations import get


def run_on_ry_dev():

    run("ls -lt")   
    
hosts = ["ubuntu@ry-dev.unglue.it"]

fabric.tasks.execute(run_on_ry_dev, hosts=hosts)

# %%
instance.state
