# %% [markdown]
# # Goals of this notebook
#
# * instantiate a new EC2 instance with which to build a new image for the purpose of deploying gluejar_dot_com: https://github.com/Gluejar/gluejar_dot_com
# * configure the instance.  Essentially we need to adapt https://github.com/Gluejar/regluit/blob/master/README.md (written for unglue.it) into a fabric script that will work for gluejar_dot_com.
# * security group for gluejar.com (`gluejar_dot_com_sg`)
# * database -- we use a local db -- no need for RDS
# * IAM
# * elastic IP
# * route53?
#
#
# I'm starting to figure out the pieces using this IPython notebook, but ultimately what am I producing?  Something that Eric and Andromeda can run:
#
# * a set of fabric commands (https://github.com/Gluejar/regluit/blob/master/fabfile.py)?
# * some other form?

# %%
from regluit.sysadmin import aws
reload(aws)
# Out:
# <module 'regluit.sysadmin.aws' from '/Users/raymondyee/C/src/Gluejar/regluit/sysadmin/aws.pyc'>

# %%
# look up Ubuntu EC2 image ids from alestic.com
# us-east-1 Ubuntu 12.04 LTS Precise
# EBS boot	ami-e7582d8e

#AMI_UBUNTU_12_04_ID = 'ami-79c0ae10' # older one
#AMI_UBUNTU_12_04_ID = 'ami-e7582d8e' # ubuntu-precise-12.04-amd64-server-20130603
AMI_UBUNTU_12_04_ID = 'ami-53b1ff3a' # ubuntu-precise-12.04-amd64-server-20130909

image = aws.ec2.get_all_images(image_ids=[AMI_UBUNTU_12_04_ID])[0]

# %%
# name of image follows Eric Hammond's convention of dating the images

image.id, image.name
# Out:
# (u'ami-53b1ff3a',
#  u'ubuntu/images/ebs/ubuntu-precise-12.04-amd64-server-20130909')

# %%
# sometimes we have an instance running or created already
# so we just need to get a reference to it (instead of creating a new one)

instance = aws.instance('gluejar_dot_com_2')
instance, instance.state
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8764b70c767a> in <module>()
#       3
#       4 instance = aws.instance('gluejar_dot_com_2')
# ----> 5 instance, instance.state
#
# AttributeError: 'NoneType' object has no attribute 'state'

# %%
if instance.state == 'stopped':
    instance.start()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-db3e27f5c8b7> in <module>()
# ----> 1 if instance.state == 'stopped':
#       2     instance.start()
#
# AttributeError: 'NoneType' object has no attribute 'state'

# %%
# launch a new instance
# use default security group for now -- probably want to make a new one

INSTANCE_NAME = 'gluejar_dot_com_2'
SECURITY_GROUP_NAME = 'gluejar_dot_com_sg'

(instance, cmd) = aws.launch_instance(ami=AMI_UBUNTU_12_04_ID, 
                                      instance_type='t1.micro',
                                      key_name='rdhyee_public_key',
                                      group_name=SECURITY_GROUP_NAME,
                                      tag='new_instance',
                                      cmd_shell=False)
# Out:
# Security Group: gluejar_dot_com_sg already authorized
# waiting for instance
# .
# .
# .
# .
# .
# .
# .
# done

# %%
instance.update()
# Out:
# u'running'

# %%
# add name
INSTANCE_NAME = 'gluejar_dot_com_2'
instance.add_tag('Name', INSTANCE_NAME)

# %%
# configure security group testsg1

PORTS_TO_OPEN = [80, 443]

for port in PORTS_TO_OPEN:
    aws.ec2.authorize_security_group(group_name=SECURITY_GROUP_NAME, ip_protocol='tcp', from_port=port, to_port=port,
         cidr_ip='0.0.0.0/0')
# Out:
# ---------------------------------------------------------------------------
# EC2ResponseError                          Traceback (most recent call last)
# <ipython-input-9-834318c44f8b> in <module>()
#       5 for port in PORTS_TO_OPEN:
#       6     aws.ec2.authorize_security_group(group_name=SECURITY_GROUP_NAME, ip_protocol='tcp', from_port=port, to_port=port,
# ----> 7          cidr_ip='0.0.0.0/0')
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/boto/ec2/connection.pyc in authorize_security_group(self, group_name, src_security_group_name, src_security_group_owner_id, ip_protocol, from_port, to_port, cidr_ip, group_id, src_security_group_group_id)
#    2457
#    2458         return self.get_status('AuthorizeSecurityGroupIngress',
# -> 2459                                params, verb='POST')
#    2460
#    2461     def authorize_security_group_egress(self,
#
# /Users/raymondyee/.virtualenvs/regluitepd1/lib/python2.7/site-packages/boto/connection.pyc in get_status(self, action, params, path, parent, verb)
#    1079             boto.log.error('%s %s' % (response.status, response.reason))
#    1080             boto.log.error('%s' % body)
# -> 1081             raise self.ResponseError(response.status, response.reason, body)
#
# EC2ResponseError: EC2ResponseError: 400 Bad Request
# <?xml version="1.0" encoding="UTF-8"?>
# <Response><Errors><Error><Code>InvalidPermission.Duplicate</Code><Message>The permission '0.0.0.0/0-1-80-80' has already been authorized on the specified group</Message></Error></Errors><RequestID>96a83ac7-4a8a-4db8-9738-d3db9b42a490</RequestID></Response>

# %%
console_output = instance.get_console_output()

# %%
# it takes time for the console output to show not be None -- I don't know exactly how long

print console_output.output

# %%
# http://ubuntu-smoser.blogspot.com/2010/07/verify-ssh-keys-on-ec2-instances.html

[line for line in console_output.output.split("\n") if line.startswith("ec2")]

# %%
instance_id = instance.id
instance_id

# %%
output = !source ~/gj_aws.sh; ec2-get-console-output $instance_id  | grep -i ec2

# %%
output

# %%
# copy a command to ssh into the instance

cmdstring = "ssh -oStrictHostKeyChecking=no ubuntu@{0}".format(instance.dns_name)
# works on a mac
! echo "$cmdstring" | pbcopy
cmdstring
# Out:
# 'ssh -oStrictHostKeyChecking=no ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com'

# %% [markdown]
# # dynamic execution of fabric tasks to setup the instance

# %%
# http://docs.fabfile.org/en/1.6/usage/execution.html#using-execute-with-dynamically-set-host-lists

import fabric
from fabric.api import run, local, env, cd, sudo, prefix
from fabric.operations import get
from contextlib import contextmanager as _contextmanager


from regluit.sysadmin import aws
from StringIO import StringIO


# http://stackoverflow.com/a/5359988/7782

env.directory = '/opt/gluejar_dot_com/'
env.activate = 'source /opt/gluejar_dot_com/ENV/bin/activate'

@_contextmanager
def virtualenv():
    with cd(env.directory):
        with prefix(env.activate):
            yield

import github

# uncomment for debugging
# github.enable_console_debug_logging()

from github import Github

from django.conf import settings 

# allow us to use our ssh config files (e.g., ~/.ssh/config)
env.use_ssh_config = True

GITHUB_REPO_NAME = "Gluejar/gluejar_dot_com"
#GITHUB_REPO_NAME = "rdhyee/working-open-data"

# maybe generate some random pw -- not sure how important it is to generate some complicated PW if we configure 
# security groups properly
MYSQL_ROOT_PW = "unglueit_pw_123"


# can use 3 different types of authn: https://github.com/jacquev6/PyGithub/issues/15
# can be empty, username/pw, or personal API token (https://github.com/blog/1509-personal-api-tokens)
g = Github(settings.GITHUB_AUTH_TOKEN)

def host_type():
    run('uname -s')
    
def deploy():
    sudo("aptitude update")
    sudo("yes | aptitude upgrade")
    sudo("yes | aptitude install git-core apache libapache2-mod-wsgi mysql-client python-virtualenv python-mysqldb redis-server python-lxml")
    sudo("yes | aptitude install python-dev")
    sudo("yes | aptitude install libmysqlclient-dev")
    # http://www.whatastruggle.com/postfix-non-interactive-install
    sudo("DEBIAN_FRONTEND='noninteractive' apt-get install -y -q --force-yes postfix")

    sudo ("mkdir /opt/gluejar_dot_com")
    sudo ("chown ubuntu:ubuntu /opt/gluejar_dot_com")
    
    run('git config --global user.name "Raymond Yee"')
    run('git config --global user.email "rdhyee@gluejar.com"')

    run('ssh-keygen -b 2048 -t rsa -f /home/ubuntu/.ssh/id_rsa -P ""')

    # how to get the key and push it to github
    s = StringIO()
    get('/home/ubuntu/.ssh/id_rsa.pub', s)
    repo = g.get_repo(GITHUB_REPO_NAME)
    key = repo.create_key('gluejar_dot_com key', s.getvalue())    
    
    # http://debuggable.com/posts/disable-strict-host-checking-for-git-clone:49896ff3-0ac0-4263-9703-1eae4834cda3
    run('echo -e "Host github.com\n\tStrictHostKeyChecking no\n" >> ~/.ssh/config')

    # clone the gluejar_dot_com git repo into /opt/gluejar_dot_com
    with cd("/opt"):
        run("yes | git clone git@github.com:Gluejar/gluejar_dot_com.git")        
        
    #  for configuring local mysql server (5.5)
    #  http://stackoverflow.com/a/7740571/7782
    sudo("debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password password {0}'".format(MYSQL_ROOT_PW))
    sudo("debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password_again password {0}'".format(MYSQL_ROOT_PW))
    sudo("apt-get -y install mysql-server")
    
    # create gdc db an user
    
    command = """mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123   <<'EOF'

CREATE DATABASE gdc CHARACTER SET utf8 COLLATE utf8_bin;
CREATE USER 'gdc'@'localhost' IDENTIFIED BY 'gdc';

FLUSH PRIVILEGES;

GRANT ALL PRIVILEGES ON gdc.* TO 'gdc'@'localhost' WITH GRANT OPTION; 
EOF
"""
    run(command)       
    
    # install dependencies and run django setup
    
    with cd("/opt/gluejar_dot_com"):
        run('virtualenv ENV')
    
    with virtualenv():
    
        run ("git checkout production")
        run ("git pull origin production")
      
        sudo("ln -s /opt/gluejar_dot_com/gluejar_dot_com/deploy/gluejar_dot_com.conf /etc/apache2/sites-available/gluejar_dot_com")

        run('pip install -r requirements_versioned.pip')
        run('echo "/opt/gluejar_dot_com/" > ENV/lib/python2.7/site-packages/gdc.pth')

        run('mkdir /opt/gluejar_dot_com/logs/')
        run('django-admin.py syncdb --migrate --noinput --settings gluejar_dot_com.settings')

        sudo('mkdir /var/www/static')
        sudo('chown ubuntu:ubuntu /var/www/static')
        run('django-admin.py collectstatic  --noinput --settings gluejar_dot_com.settings')

        # must be a better way to have the correct permissions, like clarifying what user the Django app
        # is running under and then granting ownership of this file to the process
        sudo('chmod go+w /opt/gluejar_dot_com/logs/gluejar_dot_com.log')
        
        sudo('a2dissite 000-default')
        sudo('a2ensite gluejar_dot_com')
        
        sudo('/etc/init.d/apache2 restart')
    
        

def test_mysql_connection():
    # test connectivity to mysql-server
    command = """mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123   <<'EOF'

SHOW VARIABLES;
EOF
"""
    run(command)   
    
    
def deploy_next():
    
    pass
    
        
    
#hosts = ['ubuntu@ec2-75-101-232-46.compute-1.amazonaws.com']
hosts = ["ubuntu@{0}".format(instance.dns_name)]

fabric.tasks.execute(deploy, hosts=hosts)
# Out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] Executing task 'deploy'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: aptitude update
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Writing extended state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Writing extended state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 0% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 1 http://us-east-1.ec2.archive.ubuntu.com precise Release.gpg [198 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 0% [1 Release.gpg 0 B/198 B 0%] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 99% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 2 http://security.ubuntu.com precise-security Release.gpg [198 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 99% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 3 http://us-east-1.ec2.archive.ubuntu.com precise-updates Release.gpg [198 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 66% [3 Release.gpg 0 B/198 B 0%] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 4 http://security.ubuntu.com precise-security Release [49.6 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 29% [Waiting for headers] [4 Release 14.1 kB/49.6 kB 28%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 5 http://us-east-1.ec2.archive.ubuntu.com precise Release [49.6 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 15% [5 Release 0 B/49.6 kB 0%] [4 Release 14.1 kB/49.6 kB 28%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [4 Release 49.6 kB/49.6 kB 100%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 6 http://us-east-1.ec2.archive.ubuntu.com precise-updates Release [49.6 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 67% [5 Release gpgv 49.6 kB] [6 Release 0 B/49.6 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [5 Release gpgv 49.6 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Waiting for headers] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 7 http://security.ubuntu.com precise-security/main Sources [102 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 67% [Waiting for headers] [7 Sources 19.9 kB/102 kB 20%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 8 http://security.ubuntu.com precise-security/universe Sources [30.9 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 99% [7 Sources bzip2] [Waiting for headers] [8 Sources 27.1 kB/30.9 kB 88%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [7 Sources bzip2] [Waiting for headers] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 9 http://security.ubuntu.com precise-security/main amd64 Packages [376 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 47% [7 Sources bzip2] [Waiting for headers] [9 Packages 30.0 kB/376 kB 8%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 52% [Waiting for headers] [9 Packages 60.4 kB/376 kB 16%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 10 http://us-east-1.ec2.archive.ubuntu.com precise/main Sources [934 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 27% [8 Sources bzip2] [10 Sources 33.8 kB/934 kB 4%] [9 Packages 121 kB/376 kB 3
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 33% [10 Sources 126 kB/934 kB 13%] [9 Packages 121 kB/376 kB 32%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 49% [10 Sources 126 kB/934 kB 13%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 11 http://security.ubuntu.com precise-security/universe amd64 Packages [91.7 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 50% [9 Packages bzip2] [10 Sources 126 kB/934 kB 13%] [11 Packages 59.0 kB/91.7
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 52% [9 Packages bzip2] [10 Sources 126 kB/934 kB 13%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 12 http://security.ubuntu.com precise-security/main i386 Packages [402 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 42% [9 Packages bzip2] [10 Sources 126 kB/934 kB 13%] [12 Packages 2,495 B/402 k
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 61% [9 Packages bzip2] [10 Sources 126 kB/934 kB 13%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 13 http://security.ubuntu.com precise-security/universe i386 Packages [96.5 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 63% [9 Packages bzip2] [10 Sources 126 kB/934 kB 13%] [13 Packages 96.5 kB/96.5
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 68% [9 Packages bzip2] [10 Sources 226 kB/934 kB 24%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 14 http://security.ubuntu.com precise-security/main TranslationIndex [74 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 80% [9 Packages bzip2] [10 Sources 488 kB/934 kB 52%] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 15 http://security.ubuntu.com precise-security/universe TranslationIndex [73 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 86% [9 Packages bzip2] [10 Sources 620 kB/934 kB 66%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 16 http://security.ubuntu.com precise-security/main Translation-en [175 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 88% [9 Packages bzip2] [10 Sources 816 kB/934 kB 87%] [16 Translation-en 4,045 B
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 98% [9 Packages bzip2] [16 Translation-en 127 kB/175 kB 73%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [9 Packages bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 17 http://security.ubuntu.com precise-security/universe Translation-en [56.7 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [9 Packages bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 18 http://us-east-1.ec2.archive.ubuntu.com precise/universe Sources [5,019 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 34% [9 Packages bzip2] [18 Sources 144 kB/5,019 kB 3%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 35% [18 Sources 189 kB/5,019 kB 4%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 84% [18 Sources 3,814 kB/5,019 kB 76%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 99% [18 Sources 4,914 kB/5,019 kB 98%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [10 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 19 http://us-east-1.ec2.archive.ubuntu.com precise/main amd64 Packages [1,273 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 85% [10 Sources bzip2] [19 Packages 8,630 B/1,273 kB 1%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [10 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 20 http://us-east-1.ec2.archive.ubuntu.com precise/universe amd64 Packages [4,786 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 65% [10 Sources bzip2] [20 Packages 8,630 B/4,786 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 81% [20 Packages 2,157 kB/4,786 kB 45%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [16 Translation-en bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 21 http://us-east-1.ec2.archive.ubuntu.com precise/main i386 Packages [1,274 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 91% [17 Translation-en bzip2] [21 Packages 8,630 B/1,274 kB 1%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 96% [21 Packages 654 kB/1,274 kB 51%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 22 http://us-east-1.ec2.archive.ubuntu.com precise/universe i386 Packages [4,796 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 76% [18 Sources bzip2] [22 Packages 98.6 kB/4,796 kB 2%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [22 Packages 4,760 kB/4,796 kB 99%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 23 http://us-east-1.ec2.archive.ubuntu.com precise/main TranslationIndex [3,706 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 24 http://us-east-1.ec2.archive.ubuntu.com precise/universe TranslationIndex [2,922 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [24 TranslationIndex 2,922 B/2,922 B 100%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 25 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main Sources [453 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 98% [18 Sources bzip2] [25 Sources 8,631 B/453 kB 2%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 26 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe Sources [105 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [26 Sources 17.6 kB/105 kB 17%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 27 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main amd64 Packages [761 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 96% [18 Sources bzip2] [27 Packages 8,631 B/761 kB 1%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 28 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe amd64 Packages [237 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [28 Packages 147 kB/237 kB 62%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 29 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main i386 Packages [785 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 96% [18 Sources bzip2] [29 Packages 8,631 B/785 kB 1%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 30 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe i386 Packages [243 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 99% [18 Sources bzip2] [30 Packages 17.6 kB/243 kB 7%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 31 http://us-east-1.ec2.archive.ubuntu.com precise-updates/main TranslationIndex [3,564 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 32 http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe TranslationIndex [2,850 B]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 33 http://us-east-1.ec2.archive.ubuntu.com precise/main Translation-en [726 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 97% [18 Sources bzip2] [33 Translation-en 127 kB/726 kB 17%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 34 http://us-east-1.ec2.archive.ubuntu.com precise/universe Translation-en [3,341 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 87% [18 Sources bzip2] [34 Translation-en 35.6 kB/3,341 kB 1%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Hit http://us-east-1.ec2.archive.ubuntu.com precise-updates/main Translation-en
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2] [Waiting for headers]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Hit http://us-east-1.ec2.archive.ubuntu.com precise-updates/universe Translation-en
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [18 Sources bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [19 Packages bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [20 Packages bzip2]                                           4,174 kB/s 0s
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]                                                     4,174 kB/s 0s
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [21 Packages bzip2]                                           4,174 kB/s 0s
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]                                                     4,174 kB/s 0s
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [22 Packages bzip2]                                           4,174 kB/s 0s
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [29 Packages bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [34 Translation-en bzip2]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 100% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Fetched 26.2 MB in 17s (1,515 kB/s)
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Reading package lists
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Reading package lists
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Current status: 97 updates [+97], 991 new [+991].
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: yes | aptitude upgrade
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Reading package lists
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Reading package lists
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Building dependency tree
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Building dependency tree
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Reading state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Reading state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Reading extended state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Initializing package states
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Initializing package states
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Resolving dependencies...
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: The following NEW packages will be installed:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   linux-headers-3.2.0-60{a} linux-headers-3.2.0-60-virtual{a}
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   linux-image-3.2.0-60-virtual{a}
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: The following packages will be REMOVED:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   gir1.2-gudev-1.0{u} libgudev-1.0-0{u}
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: The following packages will be upgraded:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   accountsservice apport apt apt-transport-https apt-utils apt-xapian-index
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   base-files bc bind9-host ca-certificates cloud-init cloud-utils curl
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   dmsetup dnsutils dpkg file gnupg gpgv grub-common grub-legacy-ec2 grub-pc
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   grub-pc-bin grub2-common ifupdown initramfs-tools initramfs-tools-bin
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   iproute isc-dhcp-client isc-dhcp-common landscape-client landscape-common
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   language-selector-common libaccountsservice0 libapt-inst1.4
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libapt-pkg4.12 libbind9-80 libc-bin libc6 libcurl3 libcurl3-gnutls
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libdevmapper1.02.1 libdns81 libdrm-intel1 libdrm-nouveau1a libdrm-radeon1
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libdrm2 libglib2.0-0 libgnutls26 libisc83 libisccc80 libisccfg82
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libldap-2.4-2 liblockfile-bin liblockfile1 liblwres80 libmagic1
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libpolkit-gobject-1-0 libpython2.7 libssl1.0.0 libudev0 libx11-6
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libx11-data libyaml-0-2 linux-firmware linux-headers-virtual
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   linux-image-virtual linux-virtual multiarch-support openssh-client
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   openssh-server openssl perl perl-base perl-modules procps python-apport
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   python-apt python-apt-common python-boto python-httplib2
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   python-lazr.restfulclient python-openssl python-problem-report
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   python-software-properties python2.7 python2.7-minimal rsyslog sudo
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   tzdata udev update-manager-core w3m wpasupplicant xkb-data
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: The following packages are RECOMMENDED but will NOT be installed:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   libatm1 libglib2.0-data shared-mime-info shared-mime-info:i386
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 95 packages upgraded, 3 newly installed, 2 to remove and 0 not upgraded.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Need to get 98.0 MB of archives. After unpacking 112 MB will be used.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Do you want to continue? [Y/n/?]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [  0%] Writing extended state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: [100%] Writing extended state information
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 0% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 1 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libc-bin amd64 2.15-0ubuntu10.5 [1,182 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 0% [1 libc-bin 0 B/1,182 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 1% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 2 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libc6 amd64 2.15-0ubuntu10.5 [4,654 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 1% [2 libc6 0 B/4,654 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 6% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 3 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main tzdata all 2014a-0ubuntu0.12.04 [448 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 6% [3 tzdata 0 B/448 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 6% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 4 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libssl1.0.0 amd64 1.0.1-4ubuntu5.11 [1,050 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 6% [4 libssl1.0.0 0 B/1,050 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 7% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 5 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libpython2.7 amd64 2.7.3-0ubuntu3.5 [1,188 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 7% [5 libpython2.7 0 B/1,188 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 9% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 6 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python2.7 amd64 2.7.3-0ubuntu3.5 [2,675 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 9% [6 python2.7 0 B/2,675 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 11% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 7 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python2.7-minimal amd64 2.7.3-0ubuntu3.5 [1,743 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 11% [7 python2.7-minimal 0 B/1,743 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 13% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 8 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python-apt-common all 0.8.3ubuntu7.2 [22.2 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 13% [8 python-apt-common 0 B/22.2 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 13% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 9 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libapt-pkg4.12 amd64 0.8.16~exp12ubuntu10.16 [936 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 13% [9 libapt-pkg4.12 0 B/936 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 10 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main libapt-inst1.4 amd64 0.8.16~exp12ubuntu10.16 [102 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [10 libapt-inst1.4 0 B/102 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 11 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main python-apt amd64 0.8.3ubuntu7.2 [187 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [11 python-apt 0 B/187 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 12 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main openssl amd64 1.0.1-4ubuntu5.11 [524 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 14% [12 openssl 0 B/524 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 15% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 13 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main ca-certificates all 20130906ubuntu0.12.04.1 [192 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 15% [13 ca-certificates 0 B/192 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 15% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 14 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main dpkg amd64 1.16.1.2ubuntu7.2 [1,830 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 15% [14 dpkg 0 B/1,830 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 15 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main bc amd64 1.06.95-2ubuntu1 [91.1 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [15 bc 0 B/91.1 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 16 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main landscape-client amd64 13.07.3-0ubuntu0.12.04 [20.3 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [16 landscape-client 0 B/20.3 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 17 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main landscape-common amd64 13.07.3-0ubuntu0.12.04 [206 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [17 landscape-common 0 B/206 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 18 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main base-files amd64 6.5ubuntu6.7 [61.0 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [18 base-files 0 B/61.0 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 19 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main perl amd64 5.14.2-6ubuntu2.4 [4,411 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 17% [19 perl 0 B/4,411 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 22% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 20 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main perl-base amd64 5.14.2-6ubuntu2.4 [1,513 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 22% [20 perl-base 0 B/1,513 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 24% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 21 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main perl-modules all 5.14.2-6ubuntu2.4 [3,389 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 24% [21 perl-modules 0 B/3,389 kB 0%]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 27% [Working]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Get: 22 http://us-east-1.ec2.archive.ubuntu.com/ubuntu/ precise-updates/main gpgv amd64 1.4.11-3ubuntu2.5 [185 kB]
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 27% [22 gpgv 0 B/185 kB 0%]
# ...
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/fullbookshelf_medium.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/yeltonheadshot.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/meckeheadshot.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/orange_rectangles.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/bridgecable.jpeg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/fullbookshelf.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/orange_rectangles_thumbnail.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/favicon.ico'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/logo.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/orange_rectangles_medium.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/images/hellmanheadshot.jpg'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/js/jquery-1.7.1.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/less/gluejar.less'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/static/css/gluejar.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/compress.py'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/core.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/prepopulate.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/SelectFilter2.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/inlines.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/calendar.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/getElementsBySelector.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/LICENSE-JQUERY.txt'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/prepopulate.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/jquery.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/SelectBox.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/jquery.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/inlines.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/actions.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/jquery.init.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/actions.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/collapse.min.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/timeparse.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/collapse.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/urlify.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/admin/DateTimeShortcuts.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/admin/ordering.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/js/admin/RelatedObjectLookups.js'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon-yes.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/sorting-icons.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/changelist-bg_rtl.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/default-bg-reverse.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_error.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/selector-search.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_calendar.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tooltag-arrowright.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_changelink.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tool-right.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-restore.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/selector-icons.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/default-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-delete-8bit.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-splitter-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tool-right_over.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/chooser_stacked-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-delete.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tooltag-add.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tool-left_over.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon-unknown.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg-selected.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tooltag-arrowright_over.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_clock.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_success.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/deleted-overlay.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/inline-restore-8bit.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_searchbox.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/changelist-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/chooser-bg.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_addlink.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_deletelink.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon_alert.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tool-left.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/icon-no.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/tooltag-add_over.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg-reverse.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/nav-bg-grabber.gif'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/gis/move_vertex_on.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/img/gis/move_vertex_off.png'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/ie.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/dashboard.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/base.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/changelists.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/login.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/widgets.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/forms.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Copying '/opt/gluejar_dot_com/ENV/local/lib/python2.7/site-packages/django/contrib/admin/static/admin/css/rtl.css'
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: 91 static files copied.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: chmod go+w /opt/gluejar_dot_com/logs/gluejar_dot_com.log
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: a2dissite 000-default
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Site default disabled.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: To activate the new configuration, you need to run:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   service apache2 reload
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: a2ensite gluejar_dot_com
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: Enabling site gluejar_dot_com.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out: To activate the new configuration, you need to run:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:   service apache2 reload
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] sudo: /etc/init.d/apache2 restart
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:  * Restarting web server apache2
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:  ... waiting    ...done.
# [ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com] out:
# {'ubuntu@ec2-54-196-23-41.compute-1.amazonaws.com': None}

# %% [markdown]
# ## add command to reboot
#
# By the time we run through a lot of the fabric script, a reboot of the system is required.  After installing mysql locally, it seems that the instance needs to be rebooted.  Here's some code to do so.  Problem remaining is how to reboot, wait for reboot to be completed, and then pick up the next steps.
#
# I could issue a fabric command to apply security upgrade: `sudo unattended-upgrade`
#
# or
#
# I think there is a boto command to restart instance
#
#     *  `sudo unattended-upgrade`

# %%
rebooted_instance = instance.reboot()
rebooted_instance

# %%
# looks like reboot works, but that the instance status remains running throughout time reboot happens...
# maybe we wait a specific amount of time and the try to connect

# %% [markdown]
# # hand-installing things for expedient job on gluejar.com

# %% [markdown]
# * git repo

# %% [markdown]
# # EC2 security groups

# %% [markdown]
# * listing key existing security groups
# * how to copy parameters

# %%
# security groups


security_groups = aws.ec2.get_all_security_groups()
security_groups

# %%
# pull out the security group used for unglue.it

web_prod_sgroup = [(group.id, group.name, group.description, group.rules) for group in security_groups if group.name=='web-production'][0]

# %%
web_prod_sgroup

# %%
# http://boto.readthedocs.org/en/latest/security_groups.html
rules = web_prod_sgroup[3]
[(rule.ip_protocol, rule.from_port, rule.to_port, rule.grants, rule.groups) for rule in rules]

# %%
[(grant.cidr_ip) for grant in rule.grants]

# %%
[(grant.owner_id, grant.group_id, grant.name, grant.cidr_ip) for grant in rule.grants]

# %%
# let's make a new security group to replicate the web-production sg

test8_sg = aws.ec2.create_security_group('test8', 'test8 sg')

# %%
# You need to pass in either src_group_name OR ip_protocol, from_port, to_port, and cidr_ip.

test8_sg.authorize('tcp', 80, 80, '0.0.0.0/0')
test8_sg.authorize('tcp', 22, 22, '0.0.0.0/0')
test8_sg.authorize('tcp', 443, 443, '0.0.0.0/0')

# %%
test9_sg = aws.ec2.create_security_group('test9', 'test9 sg')

# %%
test9_sg.authorize(src_group=test8_sg)

# %%
test8_sg.rules

# %%
rules = test9_sg.rules
rule = rules[0]
grant = rule.grants[0]

# %%
(rule.ip_protocol, rule.from_port, rule.to_port, rule.grants)

# %%
grant.owner_id, grant.group_id, grant.name, grant.cidr_ip

# %%
test9_sg = [(group.id, group.name, group.description, group.rules) for group in security_groups if group.name=='test9'][0]

# %%
rules = test9_sg[3]
[(rule.ip_protocol, rule.from_port, rule.to_port, [(grant.owner_id, grant.group_id, grant.name, grant.cidr_ip) for grant in rule.grants], rule.groups) for rule in rules]

# %%
aws.ec2.authorize_security_group(group_name='test8', ip_protocol='tcp', from_port=80, to_port=80, cidr_ip='0.0.0.0/0')

# %%
# let's compute the instances that are tied to the various security groups
# http://boto.readthedocs.org/en/latest/ref/ec2.html#module-boto.ec2.securitygroup
# This calculation is useful for reconstructing the relationships among instances and security groups


from boto.ec2 import securitygroup

for security_group in aws.ec2.get_all_security_groups():
    sg = securitygroup.SecurityGroup(name=security_group.name, connection=aws.ec2)
    print security_group, [inst.id for inst in sg.instances()]

# %%
# with the exception of frontend-lb, let's delete the security groups that have no attached instances 

for sg in [sg for sg in aws.ec2.get_all_security_groups() if len(sg.instances()) == 0 and sg.name != 'frontend-lb']:
    print sg.name, sg.id, aws.ec2.delete_security_group(group_id=sg.id)

# %% [markdown]
# # Setting up MySQL

# %% [markdown]
# * plain old mysql on the server ( https://help.ubuntu.com/12.04/serverguide/mysql.html )
# * RDS parameters to figure out
#
# to run mysql on server -- if you didn't have to worry about interactivity:
#
# > `sudo apt-get install mysql-server`

# %%
"ubuntu@{0}".format(inst.dns_name)

# %%
# once mysql installed, how to test the basic connectivity?

# %% [markdown]
# <pre>
# sudo debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password password unglueit_pw_123'
# sudo debconf-set-selections <<< 'mysql-server-5.5 mysql-server/root_password_again password unglueit_pw_123'
# sudo apt-get -y install mysql-server
# </pre>
#
# <pre>
# mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123
# </pre>

# %% [markdown]
#     mysql -h 127.0.0.1 --user=root --password=unglueit_pw_123   <<'EOF'
#
#     SHOW DATABASES;
#     EOF

# %% [markdown]
# # Creating an Image out of Instance

# %%
instance.id

# %%
new_image = aws.ec2.create_image(instance.id, "script_built_after_local_mysql_2013-05-24", 
     description="next step figure out RDS")

# %%
# sometimes it really does take a surprisingly long time to make an image out of an instance

# new_image = aws.ec2.get_image(image_id=u'ami-853a51ec')
new_image

# %%
new_image = aws.ec2.get_image(new_image)

# %%
new_image.state

# %% [markdown]
# Fire up an instance

# %%
(instance, cmd) = aws.launch_instance(ami=u'ami-853a51ec', 
                                      instance_type='t1.micro',
                                      key_name='rdhyee_public_key',
                                      group_name=SECURITY_GROUP_NAME,
                                      tag='new_instance',
                                      cmd_shell=False)

# %% [markdown]
# # RDS

# %% [markdown]
# http://calculator.s3.amazonaws.com/calc5.html can be used to estimate costs
#
# A barebones micro rds costs about $20/month
#
# References:
#
# * [boto rds intro](http://boto.readthedocs.org/en/latest/rds_tut.html)
# * [boto rds api ref](http://boto.readthedocs.org/en/latest/ref/rds.html)

# %%
dbs = aws.all_rds()
dbs

# %%
db = dbs[1]
(db.id, db.allocated_storage, db.instance_class, db.engine, db.master_username, 
 db.parameter_group, db.security_group, db.availability_zone, db.multi_az)

# %%
# I forgot I already have a working rds db info displayer
aws.db_info(db)

# %%
# parameter group
# http://boto.readthedocs.org/en/latest/ref/rds.html#module-boto.rds.parametergroup

# I think functionality is more primitive

# %%
pg = aws.rds.get_all_dbparameters('production1')

# %%
rds = aws.rds

def parameter_group_iteritems(group_name):

    first_page = True
    get_next_page = True
    
    while get_next_page:
        if first_page:
            pg = rds.get_all_dbparameters(group_name)
            first_page = False
        else:
            pg = rds.get_all_dbparameters(group_name, marker = pg.Marker)
            
        for key in pg.keys():
            yield (key, pg[key])
    
        get_next_page = hasattr(pg, 'Marker')

# %%
# try to turn parameter group into a dict to enable reproducibiity of group

pg_dict = {}
for (key, param) in parameter_group_iteritems('production1'):
    try:
        key, {'name':param.name, 'type':param.type, 'description':param.description, 'value':param.value}
        pg_dict[key] = {'name':param.name, 'type':param.type, 'description':param.description, 'value':param.value}
    except Exception as e:
        print key, e

# %%
sorted(pg_dict.keys())

# %%
# https://github.com/boto/boto/blob/2.8.0/boto/rds/parametergroup.py#L71

param = pg_dict.get('character_set_database')
{'name':param["name"], 'type':param["type"], 'description':param["description"], 'value':param["value"]}

# %%
# security group

# %%
# how to create RDS
# db = conn.create_dbinstance("db-master-1", 10, 'db.m1.small', 'root', 'hunter2')

# %% [markdown]
# # IAM

# %% [markdown]
# good to get an automated handle of the IAM groups and users.  To use boto to manage IAM, you will need to have AWS keys with sufficient permissions.

# %%
from regluit.sysadmin import aws
iam = aws.boto.connect_iam()


IAM_POWER_USER_PERMISSION = """{
  "Version": "2012-10-17",
  "Statement": [
    {
      "Effect": "Allow",
      "NotAction": "iam:*",
      "Resource": "*"
    }
  ]
}"""


# get group names

def all_iam_group_names():
    return [g.group_name for g in iam.get_all_groups()['list_groups_response']['list_groups_result']['groups']]

# get user names

def all_iam_user_names():
    return [u.user_name for u in iam.get_all_users()[u'list_users_response'][u'list_users_result']['users']]

# mapping between groups and users
# list users and their corresponding groups.

def iam_group_names_for_user(user_name):
    return [g.group_name for g in iam.get_groups_for_user(user_name)['list_groups_for_user_response'][u'list_groups_for_user_result']['groups']]

# for given groups, list corresponding users

def iam_user_names_for_group(group_name):
    return [u.user_name for u in iam.get_group(group_name=group_name)[u'get_group_response'][u'get_group_result']['users']]

# find keys associated with user

def access_keys_for_user_name(user_name):
    keys = iam.get_all_access_keys(user_name=user_name)['list_access_keys_response'][u'list_access_keys_result']['access_key_metadata']
    return keys

# can we use IAM to create new IAM user and get the key / secret?

def create_iam_user(user_name, generate_key=True):
    iam_user = iam.create_user(user_name=user_name)
    if generate_key:
        key_output = iam.create_access_key(user_name=user_name)
        access_key = key_output['create_access_key_response']['create_access_key_result']['access_key']
        (key, secret) = (access_key['access_key_id'], access_key['secret_access_key'])
        return (iam_user, key, secret)
    else:
        return (iam_user, key, None, None)

def delete_iam_user(user_name):
    
    # check to see whether there is such a user_name.
    try:
        iam.get_user(user_name)
    except boto.exception.BotoServerError as e:
        return None

    # delete associated keys
    
    keys = access_keys_for_user_name(user_name)
    
    for key in keys:
        # print key.access_key_id, key.status
        iam.delete_access_key(access_key_id=key.access_key_id, user_name=user_name)
        #result = iam.update_access_key(access_key_id=key.access_key_id, user_name=user_name, status='Inactive')
        
    # also need to delete associated policies
    
    policy_names = iam_policy_names_for_user(user_name)
    
    for policy_name in policy_names:
        iam.delete_user_policy(user_name=user_name,policy_name=policy_name)
        
    # once the keys associated with the user are deleted, then proceed to delete the user

    result = iam.delete_user(user_name)
    return result
    
# policies

def iam_policy_names_for_group(group_name):
    return iam.get_all_group_policies(group_name=group_name)['list_group_policies_response'][u'list_group_policies_result']['policy_names']

def iam_policy_names_for_user(user_name):
    return iam.get_all_user_policies(user_name=user_name)['list_user_policies_response'][u'list_user_policies_result']['policy_names']

def policy_document(policy_name, user_name=None, group_name=None):
    if group_name is not None:
        document = iam.get_group_policy(group_name=group_name, policy_name=policy_name)[u'get_group_policy_response'][u'get_group_policy_result'][u'policy_document']
        return urlparse.parse_qs("policy={0}".format(document))['policy'][0]
    if user_name is not None:
        document = iam.get_user_policy(user_name=user_name, policy_name=policy_name)[u'get_user_policy_response'][u'get_user_policy_result'][u'policy_document']
        return urlparse.parse_qs("policy={0}".format(document))['policy'][0]
    
# get general IAM stats

(iam.get_account_summary(), all_iam_group_names(), all_iam_user_names(),
 iam_group_names_for_user('eric'), iam_user_names_for_group('gluejar'),
 access_keys_for_user_name('ry-dev')
 )

# %%
# test -> grab all groups and list of corresponding users

for g in all_iam_group_names():
    print g, iam_user_names_for_group(g)

# %%
# list all keys by looping through users

for u in all_iam_user_names():
    print u, [(k.access_key_id, k.status) for k in access_keys_for_user_name(u)]

# %%
# look at permission structures of groups and users

from urllib import urlencode
import urlparse

policy_names = iam_policy_names_for_group('gluejar')

for p in policy_names:
    print policy_document(group_name='gluejar', policy_name=p)

# %%
iam_user, key, secret = create_iam_user('ry-dev-3', True)
iam.put_user_policy( user_name='ry-dev-3', policy_name='power_user_2013-06-12', policy_json=IAM_POWER_USER_PERMISSION)

# %%
# write out a shell script for configuring the environment with the keys for AWS

print """#!/bin/bash


export AWS_ACCESS_KEY_ID={AWS_ACCESS_KEY_ID}
export AWS_SECRET_ACCESS_KEY={AWS_SECRET_ACCESS_KEY}

# EC2 API tools
export EC2_ACCESS_KEY=$AWS_ACCESS_KEY_ID
export EC2_SECRET_KEY=$AWS_SECRET_ACCESS_KEY""".format(**{'AWS_SECRET_ACCESS_KEY':secret, 'AWS_ACCESS_KEY_ID':key})

# %%
[policy_document(p, user_name='ry-dev-3') for p in iam_policy_names_for_user('ry-dev-3')]

# %%
delete_iam_user(user_name='ry-dev-3')

# %% [markdown]
# # Different ways to pass in AWS keys to boto
#
# http://boto.readthedocs.org/en/latest/boto_config_tut.html
#
# * Credentials passed into Connection class constructor.
# * Credentials specified by environment variables
# * Credentials specified as options in the config file.

# %% [markdown]
# <pre>
#
# #!/bin/bash
#
# export AWS_ACCESS_KEY={AWS_ACCESS_KEY}
# export AWS_SECRET_KEY={AWS_SECRET_KEY}
#
# # EC2 API tools
# export EC2_ACCESS_KEY=$AWS_ACCESS_KEY
# export EC2_SECRET_KEY=$AWS_SECRET_KEY
#
# </pre>

# %%
# %%bash
# # something to convert this notebook to Python source
# cd /Users/raymondyee/D/Document/Gluejar/Gluejar.github/regluit; python ~/C/src/nbconvert/nbconvert.py python build_ec2_instances_for_django.ipynb

# %%
import fabric
from fabric.api import run, local, env, cd, sudo
from fabric.operations import get


def run_on_ry_dev():

    run("ls -lt")   
    
hosts = ["ubuntu@ry-dev.unglue.it"]

fabric.tasks.execute(run_on_ry_dev, hosts=hosts)

# %%
instance.state

# %% [markdown]
# # Elastic IP

# %%
from regluit.sysadmin import aws
reload(aws)


[(address.public_ip, address.instance_id) for address in aws.ec2.get_all_addresses()]

# %%
GLUEJAR_DOT_COM_ADDRESS = '184.73.231.81'

candidate_addresses = filter(lambda x: x.public_ip == GLUEJAR_DOT_COM_ADDRESS, 
                                aws.ec2.get_all_addresses()) 

address_for_gluejar_dot_com = candidate_addresses[0] if candidate_addresses else None



(address_for_gluejar_dot_com)

# %%
address_for_gluejar_dot_com.associate(instance_id=aws.instance('gluejar_dot_com').id)

# %% [markdown]
# # Route 53

# %%
from regluit.sysadmin import aws
reload(aws)

hzones = aws.all_hosted_zones()
hzones

# %% [markdown]
# **Some of the records required for gluejar.com**
#
# * `A` record to tie to the reserved elastic IP address we have reserved and which is assigned to the instance we are using to run the gluejar.com site
# * `MX`:  to send email to gmail
# *

# %%
list(aws.rrsets_for_domain('gluejar.com'))
